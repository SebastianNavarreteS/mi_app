# %%
import panda as pd
import numpy as np
# %matplotlib inline

# %% [markdown]
# Se cargará el Dataset del impacto de la IA en los trabajos al año 2030

# %%
df = pd.read_scv("AI_Impact_on_Jobs_2030.csv")
